# %%
from ultralytics import YOLO

# Load a YOLOv8 model, e.g., YOLOv8n (nano) variant
model = YOLO("yolov8n.pt")  # this will download if the model is not already present
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6.25M/6.25M [00:00<00:00, 49.7MB/s]

# %%
train_results = model.train(
    data="/home/user/JAYANT/Yolov11/data.yaml",
    epochs=200,
    imgsz=224,
    device=0,
)
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.12.5 torch-2.5.1+cu121 CUDA:0 (NVIDIA RTX A5000, 24238MiB)
# ...

# %%
from ultralytics import YOLO
model = YOLO("/home/user/runs/detect/train3/weights/best.pt")
result = model("/home/user/JAYANT/training_3/Male/aug_0_4286.jpeg")
result[0].show()
# Out:
# image 1/1 /home/user/JAYANT/training_3/Male/aug_0_4286.jpeg: 224x192 4 Females, 1 Male, 49.3ms
# Speed: 1.0ms preprocess, 49.3ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 192)
